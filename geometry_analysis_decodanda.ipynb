# %%
# Imports
import pickle
from decodanda import *
np.random.seed(1)

# %%
# Analyze visual data
session_VIS = pickle.load(open('./datasets/VISp.pck', 'rb'))

dec = Decodanda(session_VIS, {'stimulus': [-1, 1], 'action': [-1, 1]}, verbose=False)
visualize_PCA(dec, mean=True, names=['A>', 'A<', 'B>', 'B<'], ndata=100)
f, axs = plt.subplots(1, 2, figsize=(7, 3.5), gridspec_kw={'width_ratios': [3, 2]})
ccgps, null_ccgps = dec.CCGP(plot=True, ax=axs[1])
perfs, null_perfs = dec.decode(0.8, plot=True, non_semantic=True, ax=axs[0])

# %%
# Analyze motor data
session_MO = pickle.load(open('./datasets/MOp.pck', 'rb'))

dec = Decodanda(session_MO, {'stimulus': [-1, 1], 'action': [-1, 1]}, verbose=False)
visualize_PCA(dec, mean=True, names=['A>', 'A<', 'B>', 'B<'], ndata=200)
f, axs = plt.subplots(1, 2, figsize=(7, 3.5), gridspec_kw={'width_ratios': [3, 2]})
ccgps, null_ccgps = dec.CCGP(plot=True, ax=axs[1])
perfs, null_perfs = dec.decode(0.8, plot=True, non_semantic=True, ax=axs[0])

# %%
# Analyze HPC data
session_HPC = pickle.load(open('./datasets/HPC.pck', 'rb'))

dec = Decodanda(session_HPC, {'stimulus': [-1, 1], 'action': [-1, 1]}, verbose=False)
visualize_PCA(dec, mean=True, names=['A>', 'A<', 'B>', 'B<'], ndata=200)
f, axs = plt.subplots(1, 2, figsize=(7, 3.5), gridspec_kw={'width_ratios': [3, 2]})
ccgps, null_ccgps = dec.CCGP(plot=True, ax=axs[1])
perfs, null_perfs = dec.decode(0.8, plot=True, non_semantic=True, ax=axs[0])

# %%
# Analyze PFC data
session_PFC = pickle.load(open('./datasets/PFC.pck', 'rb'))

dec = Decodanda(session_PFC, {'stimulus': [-1, 1], 'action': [-1, 1]}, verbose=False)
visualize_PCA(dec, mean=True, names=['A>', 'A<', 'B>', 'B<'], ndata=200)
f, axs = plt.subplots(1, 2, figsize=(7, 3.5), gridspec_kw={'width_ratios': [3, 2]})
ccgps, null_ccgps = dec.CCGP(plot=True, ax=axs[1])
perfs, null_perfs = dec.decode(0.8, plot=True, non_semantic=True, ax=axs[0])
